# %%
import numpy as np

def parse_hmm(fname):
    f = open(fname)
    line=f.readline()
    while line[0]!='#':
        line=f.readline()
    f.readline()
    f.readline()
    f.readline()
    f.readline()
    seq = []
    extras = np.zeros([0,10])
    prob = np.zeros([0,20])
    line = f.readline()
    while line[0:2]!='//':
        lineinfo = line.split()
        seq.append(lineinfo[0])
        probs_ = [2**(-float(lineinfo[i])/1000) if lineinfo[i]!='*' else 0. for i in range(2,22)]
        prob = np.concatenate((prob,np.matrix(probs_)),axis=0)

        line = f.readline()
        lineinfo = line.split()
        extras_ = [2**(-float(lineinfo[i])/1000) if lineinfo[i]!='*' else 0. for i in range(0,10)]
        extras = np.concatenate((extras,np.matrix(extras_)),axis=0)

        line = f.readline()
        assert len(line.strip())==0

        line = f.readline()
    return (''.join(seq),prob,extras)

# %%
def parse_pssm(fname):
    f = open(fname)
    # the 4th line should be the start of the PSSM data
    f.readline()
    f.readline()
    f.readline()
    seq = []
    lprob = np.zeros([0,20])
    prob = np.zeros([0,20])
    extra = np.zeros([0,2])
    line = f.readline()
    while len(line.strip())>0:
        lineinfo = line.split()
        seq.append(lineinfo[1])
        lprobs_ = [float(lineinfo[i]) for i in range(2,22)]
        lprob = np.concatenate((lprob,np.matrix(lprobs_)),axis=0)
        probs_ = [float(lineinfo[i])/100 for i in range(22,42)]
        prob = np.concatenate((prob,np.matrix(probs_)),axis=0)
        extras_ = [float(lineinfo[i]) for i in range(42,44)]
        extra = np.concatenate((extra,np.matrix(extras_)),axis=0)
        line = f.readline()

    return (''.join(seq),prob,lprob,extra)

# %%
import numpy as np

def calculate_sxgbg_features(evolutionary_profile, X):
    L, _ = evolutionary_profile.shape
    sxgbg_features = np.zeros((L, 400))

    for i in range(1, L + 1):
        for j in range(1, L + 1):
            if i >= 1 and j >= 1 and i <= L and j <= L:
                for l in range(0, min(X + 1, L - max(i, j) + 1)):  # Adjust the loop range
                    if (j - 1) * (X + 1) + l < 400:  # Ensure the index is within bounds
                        sxgbg_value = np.dot(
                            evolutionary_profile[i - 1, :], evolutionary_profile[j - 1, :]
                        )
                        sxgbg_features[i - 1, (j - 1) * (X + 1) + l] = sxgbg_value

    return sxgbg_features

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/drive/MyDrive/Hdaproject/Novel_BinaryML.csv')

# %%
import numpy as np

# Create an empty list to store hmm_arr for each PDBid
hmm_matrices = []

for i in data['PDBid']:


    hmm_mat = parse_pssm(f'/content/drive/MyDrive/Hdaproject/Novel_PSSM-20230926T090021Z-001/Novel_PSSM/{i}.txt')
    hmm_arr = np.array(hmm_mat[1])
    hmm_matrices.append(hmm_arr)

# Add the list of hmm_arr as a new column 'hmm_matrix' in the DataFrame
data['hmm_matrix'] = hmm_matrices

# %%
import numpy as np
from sklearn.decomposition import PCA

# %%
matrix_3d= np.array(data['hmm_matrix'])

# %%
import numpy as np

# Assuming 'matrix_3d' is your 3D matrix
flattened_slices = []

# Flatten each 2D slice and store them as rows in a 2D matrix
for slice in matrix_3d:
    flattened_slice = slice.flatten()
    flattened_slices.append(flattened_slice)

# Determine the maximum length (columns) among all flattened slices
max_columns = max(len(slice) for slice in flattened_slices)

# Create a 2D matrix of zeros with maximum dimensions
matrix_2d = np.zeros((len(flattened_slices), max_columns))

# Fill in the 2D matrix with the flattened slices, padding with zeros as needed
for i, slice in enumerate(flattened_slices):
    num_columns = len(slice)
    matrix_2d[i, :num_columns] = slice

# %%
import numpy as np
from sklearn.decomposition import PCA

# Assuming 'matrix_2d' is your 2D matrix
# You can optionally standardize your data (X) if needed
#X = (matrix_2d - matrix_2d.mean(axis=0)) / matrix_2d.std(axis=0)

# Choose the number of components to retain (adjust as needed)
num_components = 2

# Perform PCA
pca = PCA(n_components=num_components)
reduced_matrix = pca.fit_transform(matrix_2d)

# Principal components (eigenvectors)
principal_components = pca.components_

# Eigenvalues
eigenvalues = pca.explained_variance_

# Variance explained by each component
explained_variance_ratio = pca.explained_variance_ratio_

# %%
import matplotlib.pyplot as plt
# Plot explained variance ratio
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio vs. Number of Components')
plt.show()

# %%
pip install scikit-multilearn
# Out:
# Collecting scikit-multilearn
#   Downloading scikit_multilearn-0.2.0-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: scikit-multilearn
# Successfully installed scikit-multilearn-0.2.0

# %%
import numpy as np
import pandas as pd
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import EarlyStopping
from keras import regularizers
from sklearn import model_selection
from tensorflow.keras.regularizers import L2

# %%
import numpy as np

def calculate_sxgbg_features(evolutionary_profile, X):
    L, _ = evolutionary_profile.shape
    sxgbg_matrix = np.zeros((20, 20))
    for i in range(20):
        for j in range(20):
            sxgbg_value = 0.0
            for l in range(1,L - X):
                sxgbg_value += evolutionary_profile[l-1, i] * evolutionary_profile[l + X , j]
            sxgbg_matrix[i, j] = sxgbg_value
    return sxgbg_matrix

# %%
sxgbg_features=[]
for i in matrix_3d:
  sxgbg_features.append(calculate_sxgbg_features(i,6))

# %%
X_train,X_test,Y_train,Y_test=train_test_split(np.array(sxgbg_features),data.iloc[:,2:7],test_size=0.2,random_state=42)

# %%
from tensorflow import keras

model3 = keras.Sequential([
    keras.layers.Input(shape=(20, 20)),  # Adjust input shape to match your data
    keras.layers.Flatten(),  # Flatten the input data
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(5, activation='sigmoid')  # 5 output nodes for multi-label classification
])

model3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    baseline=None,
    restore_best_weights=True
)

# %%
history=model3.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=[X_test, Y_test],callbacks=[early_stopping],use_multiprocessing=True)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 5s 488ms/step - loss: 0.5989 - accuracy: 0.5208 - val_loss: 0.4917 - val_accuracy: 0.4000
# Epoch 2/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4244 - accuracy: 0.5104 - val_loss: 0.4893 - val_accuracy: 0.4000
# Epoch 3/100
# 2/2 [==============================] - 0s 100ms/step - loss: 0.4064 - accuracy: 0.5312 - val_loss: 0.4153 - val_accuracy: 0.4000
# Epoch 4/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.3787 - accuracy: 0.5938 - val_loss: 0.3785 - val_accuracy: 0.5600
# Epoch 5/100
# 2/2 [==============================] - 0s 95ms/step - loss: 0.3683 - accuracy: 0.6146 - val_loss: 0.3789 - val_accuracy: 0.5200
# Epoch 6/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.3415 - accuracy: 0.5625 - val_loss: 0.4122 - val_accuracy: 0.4000
# Epoch 7/100
# 2/2 [==============================] - 0s 163ms/step - loss: 0.3355 - accuracy: 0.5625 - val_loss: 0.3965 - val_accuracy: 0.4400
# Epoch 8/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.3165 - accuracy: 0.5938 - val_loss: 0.3533 - val_accuracy: 0.5600
# Epoch 9/100
# 2/2 [==============================] - 0s 144ms/step - loss: 0.3000 - accuracy: 0.6667 - val_loss: 0.3332 - val_accuracy: 0.6400
# Epoch 10/100
# 2/2 [==============================] - 0s 109ms/step - loss: 0.2874 - accuracy: 0.7188 - val_loss: 0.3423 - val_accuracy: 0.5200
# Epoch 11/100
# 2/2 [==============================] - 0s 152ms/step - loss: 0.2790 - accuracy: 0.7083 - val_loss: 0.3444 - val_accuracy: 0.5600
# Epoch 12/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.2636 - accuracy: 0.6875 - val_loss: 0.3219 - val_accuracy: 0.6000
# Epoch 13/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.2575 - accuracy: 0.7292 - val_loss: 0.3060 - val_accuracy: 0.6800
# Epoch 14/100
# 2/2 [==============================] - 0s 190ms/step - loss: 0.2409 - accuracy: 0.7708 - val_loss: 0.3205 - val_accuracy: 0.6000
# Epoch 15/100
# 2/2 [==============================] - 0s 179ms/step - loss: 0.2334 - accuracy: 0.7604 - val_loss: 0.3169 - val_accuracy: 0.6000
# Epoch 16/100
# 2/2 [==============================] - 0s 235ms/step - loss: 0.2228 - accuracy: 0.7812 - val_loss: 0.3067 - val_accuracy: 0.6400
# Epoch 17/100
# 2/2 [==============================] - 0s 91ms/step - loss: 0.2138 - accuracy: 0.8542 - val_loss: 0.2851 - val_accuracy: 0.6800
# Epoch 18/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.2071 - accuracy: 0.8438 - val_loss: 0.2915 - val_accuracy: 0.6800
# Epoch 19/100
# 2/2 [==============================] - 0s 77ms/step - loss: 0.1923 - accuracy: 0.8438 - val_loss: 0.3060 - val_accuracy: 0.6400
# Epoch 20/100
# 2/2 [==============================] - 0s 98ms/step - loss: 0.1927 - accuracy: 0.8542 - val_loss: 0.2942 - val_accuracy: 0.6000
# Epoch 21/100
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1762 - accuracy: 0.8542 - val_loss: 0.2760 - val_accuracy: 0.6800
# Epoch 22/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1750 - accuracy: 0.8438 - val_loss: 0.2726 - val_accuracy: 0.6800
# Epoch 23/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1593 - accuracy: 0.9375 - val_loss: 0.2936 - val_accuracy: 0.6400
# Epoch 24/100
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1583 - accuracy: 0.9167 - val_loss: 0.2823 - val_accuracy: 0.6000
# Epoch 25/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1458 - accuracy: 0.9062 - val_loss: 0.2557 - val_accuracy: 0.7200
# Epoch 26/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.1456 - accuracy: 0.9062 - val_loss: 0.2613 - val_accuracy: 0.7200
# Epoch 27/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.1399 - accuracy: 0.9271 - val_loss: 0.2907 - val_accuracy: 0.6800
# Epoch 28/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1319 - accuracy: 0.9271 - val_loss: 0.2807 - val_accuracy: 0.6800
# Epoch 29/100
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1254 - accuracy: 0.9062 - val_loss: 0.2579 - val_accuracy: 0.7200
# Epoch 30/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1227 - accuracy: 0.9479 - val_loss: 0.2631 - val_accuracy: 0.7200

# %%
y_pred=np.round(model3.predict(X_test))
# Out:
# 1/1 [==============================] - 0s 286ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(Y_test,y_pred)
print(accuracy)
# Out:
# 0.64

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, multilabel_confusion_matrix
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC
from tensorflow.keras.callbacks import EarlyStopping

# Load your data and perform any necessary preprocessing steps here

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(matrix_2d, data.iloc[:, 2:7], test_size=0.3, random_state=42)

# Create a more complex neural network model
model = Sequential()
model.add(Input(shape=(max_columns,)))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(5, activation='sigmoid'))  # 5 output nodes for multi-label classification

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=[AUC()])

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_data=(X_test, Y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.6831 - auc: 0.5632 - val_loss: 0.5333 - val_auc: 0.7192
# Epoch 2/100
# 2/2 [==============================] - 2s 883ms/step - loss: 0.5429 - auc: 0.7004 - val_loss: 0.4893 - val_auc: 0.7176
# Epoch 3/100
# 2/2 [==============================] - 1s 716ms/step - loss: 0.4777 - auc: 0.7563 - val_loss: 0.5106 - val_auc: 0.7300
# Epoch 4/100
# 2/2 [==============================] - 1s 561ms/step - loss: 0.4763 - auc: 0.7825 - val_loss: 0.5021 - val_auc: 0.7473
# Epoch 5/100
# 2/2 [==============================] - 1s 981ms/step - loss: 0.4271 - auc: 0.8315 - val_loss: 0.4782 - val_auc: 0.7566
# Epoch 6/100
# 2/2 [==============================] - 1s 591ms/step - loss: 0.4666 - auc: 0.8002 - val_loss: 0.4593 - val_auc: 0.7655
# Epoch 7/100
# 2/2 [==============================] - 1s 705ms/step - loss: 0.4197 - auc: 0.8342 - val_loss: 0.4505 - val_auc: 0.7720
# Epoch 8/100
# 2/2 [==============================] - 1s 654ms/step - loss: 0.3611 - auc: 0.8680 - val_loss: 0.4487 - val_auc: 0.7708
# Epoch 9/100
# 2/2 [==============================] - 1s 804ms/step - loss: 0.3741 - auc: 0.8710 - val_loss: 0.4478 - val_auc: 0.7764
# Epoch 10/100
# 2/2 [==============================] - 1s 861ms/step - loss: 0.3263 - auc: 0.8966 - val_loss: 0.4518 - val_auc: 0.7797
# Epoch 11/100
# 2/2 [==============================] - 2s 857ms/step - loss: 0.3201 - auc: 0.8961 - val_loss: 0.4632 - val_auc: 0.7761
# Epoch 12/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.3053 - auc: 0.9086 - val_loss: 0.4778 - val_auc: 0.7696
# Epoch 13/100
# 2/2 [==============================] - 2s 877ms/step - loss: 0.2907 - auc: 0.9204 - val_loss: 0.4929 - val_auc: 0.7613
# Epoch 14/100
# 2/2 [==============================] - 1s 330ms/step - loss: 0.3046 - auc: 0.9026 - val_loss: 0.4997 - val_auc: 0.7652
# Epoch 15/100
# 2/2 [==============================] - 1s 357ms/step - loss: 0.2420 - auc: 0.9453 - val_loss: 0.4901 - val_auc: 0.7808
# Epoch 16/100
# 2/2 [==============================] - 1s 369ms/step - loss: 0.2072 - auc: 0.9612 - val_loss: 0.4796 - val_auc: 0.7923
# Epoch 17/100
# 2/2 [==============================] - 1s 360ms/step - loss: 0.1862 - auc: 0.9677 - val_loss: 0.4612 - val_auc: 0.8040
# Epoch 18/100
# 2/2 [==============================] - 1s 392ms/step - loss: 0.1760 - auc: 0.9693 - val_loss: 0.4465 - val_auc: 0.8194
# Epoch 19/100
# 2/2 [==============================] - 1s 345ms/step - loss: 0.1400 - auc: 0.9867 - val_loss: 0.4614 - val_auc: 0.8203
# Epoch 20/100
# 2/2 [==============================] - 1s 335ms/step - loss: 0.1568 - auc: 0.9757 - val_loss: 0.4956 - val_auc: 0.8139
# Epoch 21/100
# 2/2 [==============================] - 1s 356ms/step - loss: 0.1133 - auc: 0.9888 - val_loss: 0.5376 - val_auc: 0.8034
# Epoch 22/100
# 2/2 [==============================] - 1s 372ms/step - loss: 0.1245 - auc: 0.9859 - val_loss: 0.5516 - val_auc: 0.8034
# Epoch 23/100
# 2/2 [==============================] - 1s 355ms/step - loss: 0.1356 - auc: 0.9808 - val_loss: 0.5327 - val_auc: 0.8158
# Epoch 24/100
# 2/2 [==============================] - 1s 334ms/step - loss: 0.0960 - auc: 0.9904 - val_loss: 0.5361 - val_auc: 0.8202
# Epoch 25/100
# 2/2 [==============================] - 1s 345ms/step - loss: 0.0892 - auc: 0.9930 - val_loss: 0.5648 - val_auc: 0.8130
# Epoch 26/100
# 2/2 [==============================] - 1s 353ms/step - loss: 0.0939 - auc: 0.9941 - val_loss: 0.5982 - val_auc: 0.8073
# Epoch 27/100
# 2/2 [==============================] - 1s 341ms/step - loss: 0.0636 - auc: 0.9963 - val_loss: 0.6422 - val_auc: 0.7934
# Epoch 28/100
# 2/2 [==============================] - 1s 465ms/step - loss: 0.0409 - auc: 0.9995 - val_loss: 0.6983 - val_auc: 0.7885

# %%
# Evaluate the model
Y_pred = model.predict(X_test)

# You can print a classification report for a more detailed analysis
print(classification_report(Y_test, Y_pred > 0.5))

# You can also print confusion matrices for each label
print(multilabel_confusion_matrix(Y_test, Y_pred > 0.5))
# Out:
# 2/2 [==============================] - 0s 25ms/step
#               precision    recall  f1-score   support
#
#            0       0.48      0.79      0.59        14
#            1       0.00      0.00      0.00         3
#            2       0.00      0.00      0.00         0
#            3       1.00      0.10      0.18        10
#            4       0.64      0.50      0.56        14
#
#    micro avg       0.54      0.46      0.50        41
#    macro avg       0.42      0.28      0.27        41
# weighted avg       0.62      0.46      0.44        41
#  samples avg       0.51      0.50      0.50        41
#
# [[[11 12]
#   [ 3 11]]
#
#  [[34  0]
#   [ 3  0]]
#
#  [[37  0]
#   [ 0  0]]
#
#  [[27  0]
#   [ 9  1]]
#
#  [[19  4]
#   [ 7  7]]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
